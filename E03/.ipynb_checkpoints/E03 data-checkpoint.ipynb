# %%
import numpy as np
import matplotlib.pyplot as mp
import scipy.fftpack as fft
from mpl_toolkits.axes_grid1 import make_axes_locatable
import matplotlib.ticker as tick
import scipy.integrate as Int
import scipy.signal as sig
from jupyterthemes import jtplot

# %%
jtplot.reset()
mp.rcParams["text.usetex"] = True
mp.rcParams["font.family"] = "serif"
mp.rcParams["figure.figsize"] = (5, 5)
mp.rcParams["figure.dpi"] = 100

# %%
def read_csv(name, save=False):
    filename = name + ".csv"
    t, Vin, Vout, Vnull = np.genfromtxt(filename, delimiter=",", skip_header=2).T
    t += abs(t.min())
    rate = len(Vin)/t.max()
    c = fft.fft(Vout)
    f = np.argmax(abs(c))/len(Vin)*rate
    
    fig, (ax1, ax2) = mp.subplots(1, 2, figsize=(5*2.5, 5))
    
    ax1.plot(t, Vin, "y-")
    ax1.grid(True)
    ax1.set_ylabel(r"$\mathrm{V_{in}}$, V")
    ax1.xaxis.set_major_formatter(tick.NullFormatter())
    #ax1.set_title(name + ", %i Hz"%f)
    
    divider = make_axes_locatable(ax1)
    ax12 = divider.append_axes("bottom", size="100%", pad=0.1)
    
    ax12.plot(t, Vout, "c-")
    ax12.grid(True)
    ax12.set_xlabel(r"time, s")
    ax12.set_ylabel(r"$\mathrm{V_{out}}$, V")
    
    ax2.plot(Vin, Vout, "y.")
    ax2.grid(True)
    ax2.set_xlabel(r"$\mathrm{V_{in}}$, V")
    ax2.set_ylabel(r"$\mathrm{V_{out}}$, V")
    
    mp.suptitle("%s, %i Hz"%(name, f))
    
    if save:
        mp.savefig(name + ".png", dpi=300, bbox_inches="tight")

    mp.show()

# %%
files = ["r1", "r2", "c1", "c2", "l1", "l2"]
for n in files:
    read_csv(n)
